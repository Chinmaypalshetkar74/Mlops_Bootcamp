# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://localhost:5000")

# %%
mlflow.set_experiment("check local host")


with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("test2",2)
# Out:
# 2025/12/21 06:51:13 INFO mlflow.tracking.fluent: Experiment with name 'check local host' does not exist. Creating a new experiment.
# 🏃 View run adaptable-flea-903 at: http://localhost:5000/#/experiments/1/runs/d68530b23b744104a72d2ee9d72c8d2f
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test2",1)
    mlflow.log_metric("test3",2)
# Out:
# 🏃 View run able-kit-406 at: http://localhost:5000/#/experiments/1/runs/60c4b374898b442d827b748139f44da1
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
import mlflow

mlflow.set_experiment("test_experiment")

with mlflow.start_run():
    mlflow.log_param("learning_rate", 0.01)
    mlflow.log_metric("accuracy", 0.95)
# Out:
# 2025/12/21 07:01:05 INFO mlflow.tracking.fluent: Experiment with name 'test_experiment' does not exist. Creating a new experiment.
# 🏃 View run serious-goose-543 at: http://localhost:5000/#/experiments/2/runs/faece59a3d164675a235e45538a78110
# 🧪 View experiment at: http://localhost:5000/#/experiments/2

# %%
import numpy as np

arr1=np.array([1,2,3])
print(arr1)
# Out:
# [1 2 3]
